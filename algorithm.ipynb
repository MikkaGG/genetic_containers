# %%
import random

class Container:
    def __init__(self, width, height, depth):
        self.width = width
        self.height = height
        self.depth = depth

class Item:
    def __init__(self, width, height, depth):
        self.width = width
        self.height = height
        self.depth = depth

class Packing:
    def __init__(self, containers):
        self.containers = containers
        self.items = []

    def add_item(self, item):
        for container in self.containers:
            if container.width >= item.width and container.height >= item.height and container.depth >= item.depth:
                self.items.append(item)
                self.containers.remove(container)
                new_containers = self.split_container(container, item)
                self.containers.extend(new_containers)
                return True
        return False

    def split_container(self, container, item):
        new_containers = []
        if container.width - item.width > 0:
            new_containers.append(Container(container.width - item.width, container.height, container.depth))
        if container.height - item.height > 0:
            new_containers.append(Container(container.width, container.height - item.height, container.depth))
        if container.depth - item.depth > 0:
            new_containers.append(Container(container.width, container.height, container.depth - item.depth))
        return new_containers

    def fitness(self):
        total_volume = sum([c.width * c.height * c.depth for c in self.containers])
        packed_volume = sum([i.width * i.height * i.depth for i in self.items])
        return packed_volume / total_volume

def init_population(containers, items, population_size):
    population = []
    for i in range(population_size):
        packing = Packing([Container(c.width, c.height, c.depth) for c in containers])
        random.shuffle(items)
        for item in items:
            packing.add_item(item)
        population.append(packing)
    return population

def evaluate_fitness(population):
    for p in population:
        p.fitness()

def selection(population):
    sorted_population = sorted(population, key=lambda x: x.fitness(), reverse=True)
    return sorted_population[0], sorted_population[1]

def crossover(parent1, parent2):
    container = random.choice(parent1.containers)
    index = parent1.containers.index(container)
    new_containers1 = parent1.containers[:index] + parent2.containers[index:]
    new_containers2 = parent2.containers[:index] + parent1.containers[index:]
    child1 = Packing(new_containers1)
    child2 = Packing(new_containers2)
    return child1, child2

def mutation(packing):
    for i in range(len(packing.items)):
        item = packing.items[i]
        if random.random() < 0.1:
            new_item = Item(random.randint(1, item.width), random.randint(1, item.height), random.randint(1, item.depth))
            packing.items[i] = new_item

def genetic_algorithm(containers, items, generations, population_size):
    population = init_population(containers, items, population_size)
    evaluate_fitness(population)
    for i in range(generations):
        parent1, parent2 = selection(population)
        child1, child2 = crossover(parent1, parent2)
        mutation(child1)
        mutation(child2)
        population.extend([child1, child2])
        evaluate_fitness(population)
    best_packing = max(population, key=lambda x: x.fitness())
    return best_packing

def initLists(count_container, count_items):
    containers = []
    items = []
    c_containers = []
    c_items = []
    for i in range(count_container):
        container = [random.randint(5, 30) for j in range(3)]
        containers.append(container)
    
    for i in range(count_items):
        item = [random.randint(5, 30) for j in range(3)]
        items.append(item)
    
    for i in range(len(containers)):
        for j in range(1):
            c_containers.append(Container(width=containers[i][j], height=containers[i][j+1], 
                                          depth=containers[i][j+2]))

    for i in range(len(items)):
        for j in range(1):
            c_items.append(Item(width=items[i][j], height=items[i][j+1], 
                                      depth=items[i][j+2]))
    return c_containers, c_items

# %%
# %%time

containers, items = initLists(100, 100)

population = init_population(containers=containers, items=items, population_size=10)
best_packing = genetic_algorithm(containers=containers, items=items, generations=100, population_size=10)

print("Containers:")
for i, container in enumerate(best_packing.containers):
    print(f"Container {i+1}: width={container.width}, height={container.height}, depth={container.depth}")
print("Items:")
for item in best_packing.items:
    print(f"Item: width={item.width}, height={item.height}, depth={item.depth}")
print(f"Fitness: {best_packing.fitness()}")
# Out:
# Containers:
# Container 1: width=11, height=6, depth=15
# Container 2: width=8, height=9, depth=8
# Container 3: width=5, height=29, depth=25
# Container 4: width=11, height=14, depth=5
# Container 5: width=8, height=9, depth=8
# Container 6: width=5, height=14, depth=23
# Container 7: width=5, height=28, depth=18
# Container 8: width=28, height=20, depth=6
# Container 9: width=14, height=16, depth=6
# Container 10: width=29, height=5, depth=15
# Container 11: width=9, height=30, depth=11
# Container 12: width=9, height=20, depth=24
# Container 13: width=9, height=6, depth=11
# Container 14: width=14, height=16, depth=5
# Container 15: width=12, height=19, depth=21
# Container 16: width=27, height=5, depth=21
# Container 17: width=16, height=6, depth=16
# Container 18: width=14, height=19, depth=6
# Container 19: width=25, height=10, depth=14
# Container 20: width=5, height=22, depth=29
# Container 21: width=28, height=19, depth=9
# Container 22: width=6, height=12, depth=16
# Container 23: width=12, height=9, depth=11
# Container 24: width=20, height=11, depth=7
# Container 25: width=10, height=12, depth=10
# Container 26: width=16, height=15, depth=12
# Container 27: width=21, height=8, depth=11
# Container 28: width=13, height=19, depth=27
# Container 29: width=24, height=7, depth=15
# Container 30: width=7, height=29, depth=25
# Container 31: width=7, height=6, depth=30
# Container 32: width=7, height=5, depth=29
# Container 33: width=6, height=21, depth=28
# Container 34: width=14, height=30, depth=7
# Container 35: width=22, height=28, depth=11
# Container 36: width=14, height=7, depth=25
# Container 37: width=23, height=23, depth=11
# Container 38: width=4, height=15, depth=29
# Container 39: width=7, height=29, depth=29
# Container 40: width=29, height=2, depth=27
# Container 41: width=7, height=13, depth=23
# Container 42: width=29, height=1, depth=23
# Container 43: width=29, height=13, depth=5
# Container 44: width=14, height=12, depth=28
# Container 45: width=19, height=2, depth=28
# Container 46: width=19, height=12, depth=6
# Container 47: width=3, height=17, depth=25
# Container 48: width=18, height=2, depth=25
# Container 49: width=18, height=17, depth=4
# Container 50: width=1, height=18, depth=16
# Container 51: width=7, height=9, depth=16
# Container 52: width=7, height=18, depth=3
# Container 53: width=5, height=25, depth=27
# Container 54: width=26, height=5, depth=27
# Container 55: width=26, height=25, depth=15
# Container 56: width=18, height=3, depth=28
# Container 57: width=18, height=28, depth=15
# Container 58: width=3, height=25, depth=29
# Container 59: width=28, height=4, depth=29
# Container 60: width=3, height=10, depth=11
# Container 61: width=25, height=2, depth=11
# Container 62: width=25, height=10, depth=4
# Container 63: width=2, height=28, depth=18
# Container 64: width=15, height=8, depth=18
# Container 65: width=16, height=2, depth=28
# Container 66: width=16, height=20, depth=17
# Container 67: width=7, height=29, depth=15
# Container 68: width=26, height=2, depth=15
# Container 69: width=26, height=29, depth=8
# Container 70: width=1, height=30, depth=22
# Container 71: width=27, height=2, depth=22
# Container 72: width=4, height=6, depth=27
# Container 73: width=19, height=6, depth=7
# Container 74: width=7, height=30, depth=17
# Container 75: width=27, height=4, depth=17
# Container 76: width=27, height=30, depth=1
# Container 77: width=4, height=17, depth=18
# Container 78: width=21, height=2, depth=18
# Container 79: width=21, height=17, depth=4
# Container 80: width=29, height=9, depth=24
# Container 81: width=29, height=19, depth=9
# Container 82: width=21, height=3, depth=26
# Container 83: width=21, height=17, depth=18
# Container 84: width=2, height=15, depth=19
# Container 85: width=16, height=1, depth=19
# Container 86: width=16, height=15, depth=14
# Container 87: width=5, height=4, depth=19
# Container 88: width=5, height=22, depth=7
# Container 89: width=22, height=6, depth=24
# Container 90: width=22, height=17, depth=12
# Container 91: width=8, height=26, depth=6
# Container 92: width=28, height=1, depth=6
# Container 93: width=28, height=26, depth=1
# Container 94: width=2, height=21, depth=12
# Container 95: width=28, height=21, depth=3
# Container 96: width=1, height=19, depth=20
# Container 97: width=9, height=14, depth=20
# Container 98: width=9, height=19, depth=4
# Container 99: width=3, height=29, depth=30
# Container 100: width=12, height=11, depth=30
# Container 101: width=12, height=29, depth=15
# Container 102: width=2, height=7, depth=26
# Container 103: width=2, height=15, depth=25
# Container 104: width=29, height=3, depth=25
# Container 105: width=29, height=15, depth=2
# Container 106: width=11, height=7, depth=27
# Container 107: width=2, height=29, depth=27
# Container 108: width=8, height=12, depth=27
# Container 109: width=8, height=29, depth=14
# Container 110: width=3, height=30, depth=27
# Container 111: width=16, height=6, depth=27
# Container 112: width=6, height=18, depth=21
# Container 113: width=30, height=18, depth=1
# Container 114: width=4, height=15, depth=24
# Container 115: width=20, height=5, depth=24
# Container 116: width=20, height=15, depth=17
# Container 117: width=2, height=23, depth=11
# Container 118: width=12, height=15, depth=11
# Container 119: width=12, height=23, depth=6
# Container 120: width=13, height=10, depth=15
# Container 121: width=25, height=1, depth=15
# Container 122: width=25, height=10, depth=2
# Container 123: width=7, height=19, depth=27
# Container 124: width=25, height=19, depth=4
# Container 125: width=1, height=27, depth=14
# Container 126: width=16, height=10, depth=14
# Container 127: width=16, height=27, depth=3
# Container 128: width=2, height=19, depth=17
# Container 129: width=10, height=1, depth=17
# Container 130: width=10, height=19, depth=1
# Container 131: width=2, height=27, depth=29
# Container 132: width=9, height=7, depth=29
# Container 133: width=9, height=27, depth=1
# Container 134: width=6, height=20, depth=17
# Container 135: width=16, height=4, depth=17
# Container 136: width=16, height=20, depth=9
# Container 137: width=9, height=20, depth=18
# Container 138: width=26, height=20, depth=4
# Container 139: width=4, height=25, depth=24
# Container 140: width=22, height=3, depth=24
# Container 141: width=22, height=25, depth=5
# Container 142: width=1, height=30, depth=11
# Container 143: width=29, height=30, depth=3
# Container 144: width=1, height=26, depth=13
# Container 145: width=18, height=5, depth=13
# Container 146: width=18, height=26, depth=4
# Container 147: width=3, height=30, depth=25
# Container 148: width=9, height=9, depth=25
# Container 149: width=1, height=30, depth=26
# Container 150: width=17, height=5, depth=26
# Container 151: width=17, height=30, depth=9
# Container 152: width=7, height=26, depth=9
# Container 153: width=30, height=5, depth=9
# Container 154: width=30, height=26, depth=4
# Container 155: width=2, height=16, depth=23
# Container 156: width=30, height=8, depth=23
# Container 157: width=30, height=16, depth=10
# Container 158: width=6, height=6, depth=28
# Container 159: width=27, height=1, depth=28
# Container 160: width=27, height=6, depth=17
# Container 161: width=7, height=20, depth=24
# Container 162: width=26, height=1, depth=24
# Container 163: width=26, height=20, depth=12
# Container 164: width=30, height=7, depth=11
# Container 165: width=30, height=19, depth=1
# Container 166: width=2, height=16, depth=27
# Container 167: width=26, height=4, depth=27
# Container 168: width=26, height=16, depth=4
# Container 169: width=28, height=5, depth=12
# Container 170: width=28, height=14, depth=6
# Container 171: width=3, height=16, depth=26
# Container 172: width=21, height=4, depth=26
# Container 173: width=30, height=1, depth=21
# Container 174: width=30, height=8, depth=11
# Container 175: width=10, height=13, depth=20
# Container 176: width=26, height=5, depth=20
# Container 177: width=26, height=13, depth=1
# Container 178: width=1, height=21, depth=20
# Container 179: width=16, height=2, depth=20
# Container 180: width=16, height=21, depth=4
# Container 181: width=25, height=1, depth=27
# Container 182: width=25, height=7, depth=1
# Container 183: width=1, height=30, depth=27
# Container 184: width=12, height=1, depth=27
# Container 185: width=12, height=30, depth=5
# Container 186: width=1, height=10, depth=21
# Container 187: width=16, height=10, depth=13
# Container 188: width=3, height=9, depth=25
# Container 189: width=22, height=2, depth=25
# Container 190: width=22, height=9, depth=6
# Container 191: width=16, height=6, depth=15
# Container 192: width=16, height=27, depth=3
# Container 193: width=1, height=22, depth=18
# Container 194: width=27, height=22, depth=8
# Container 195: width=8, height=10, depth=29
# Container 196: width=23, height=1, depth=29
# Container 197: width=23, height=10, depth=12
# Container 198: width=8, height=19, depth=15
# Container 199: width=27, height=5, depth=15
# Container 200: width=27, height=19, depth=1
# Container 201: width=1, height=14, depth=29
# Container 202: width=7, height=3, depth=29
# Container 203: width=13, height=5, depth=14
# Container 204: width=13, height=23, depth=3
# Container 205: width=7, height=10, depth=23
# Container 206: width=30, height=10, depth=5
# Items:
# Item: width=19, height=5, depth=29
# Item: width=15, height=30, depth=5
# Item: width=16, height=29, depth=29
# Item: width=13, height=28, depth=16
# Item: width=22, height=12, depth=18
# Item: width=5, height=10, depth=22
# Item: width=15, height=15, depth=21
# Item: width=6, height=9, depth=13
# Item: width=21, height=20, depth=12
# Item: width=18, height=25, depth=13
# Item: width=25, height=21, depth=29
# Item: width=22, height=8, depth=7
# Item: width=13, height=20, depth=18
# Item: width=16, height=18, depth=11
# Item: width=19, height=27, depth=7
# Item: width=26, height=28, depth=22
# Item: width=15, height=6, depth=20
# Item: width=20, height=26, depth=16
# Item: width=17, height=15, depth=14
# Item: width=29, height=10, depth=15
# Item: width=21, height=14, depth=8
# Item: width=14, height=14, depth=5
# Item: width=5, height=18, depth=12
# Item: width=22, height=11, depth=12
# Item: width=20, height=25, depth=5
# Item: width=26, height=21, depth=9
# Item: width=8, height=5, depth=16
# Item: width=9, height=18, depth=15
# Item: width=5, height=7, depth=26
# Item: width=27, height=12, depth=23
# Item: width=11, height=12, depth=27
# Item: width=6, height=17, depth=13
# Item: width=13, height=24, depth=27
# Item: width=24, height=10, depth=20
# Item: width=16, height=10, depth=7
# Item: width=10, height=8, depth=5
# Item: width=12, height=9, depth=13
# Item: width=18, height=12, depth=23
# Item: width=15, height=17, depth=11
# Item: width=8, height=18, depth=16
# Item: width=7, height=20, depth=28
# Item: width=10, height=16, depth=8
# Item: width=17, height=20, depth=14
# Item: width=18, height=22, depth=19
# Item: width=28, height=30, depth=8
# Item: width=30, height=9, depth=12
# Item: width=17, height=21, depth=9
# Item: width=6, height=21, depth=25
# Item: width=16, height=25, depth=17
# Item: width=23, height=21, depth=5
# Item: width=28, height=8, depth=13
# Item: width=21, height=5, depth=11
# Item: width=19, height=19, depth=12
# Item: width=30, height=12, depth=10
# Item: width=24, height=12, depth=23
# Item: width=28, height=9, depth=6
# Item: width=9, height=22, depth=9
# Item: width=18, height=12, depth=26
# Item: width=30, height=7, depth=10
# Item: width=16, height=8, depth=19
# Item: width=15, height=19, depth=16
# Item: width=25, height=6, depth=26
# Item: width=11, height=29, depth=22
# Item: width=15, height=10, depth=8
# Item: width=19, height=7, depth=19
# Item: width=16, height=21, depth=12
# Item: width=26, height=22, depth=10
# Item: width=15, height=9, depth=17
# Item: width=19, height=14, depth=14
# Item: width=6, height=11, depth=29
# Item: width=13, height=18, depth=11
# Item: width=23, height=10, depth=18
# Fitness: 0.677124481811926
# CPU times: total: 422 ms
# Wall time: 431 ms
